# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Alice Zhao**
# Credit Analyst

# %% [markdown]
# *I am interested in data science because it is the future and companies are dependent on data to grow and thrive.*

# %% [markdown]
# ### My code in cell 5 is supposed to show a simple math calculation

# %%
print(1+2)

# %% [markdown]
# This is a sentence above the horizontal separator.
# ***
# 1. this is the first line using numbered list
# - [click me](http://google.com)
